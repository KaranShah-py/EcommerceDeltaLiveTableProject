-- %% [markdown]
-- #**Creating the Catalog and Schema**

-- %%
-- CREATE CATALOG IF NOT EXISTS EcommerceDataset;

-- %%
-- CREATE SCHEMA IF NOT EXISTS EcommerceDataset.landingLayer;
-- CREATE VOLUME IF NOT EXISTS EcommerceDataset.landingLayer.LandingData;

-- CREATE SCHEMA IF NOT EXISTS EcommerceDataset.BronzeLayer;
-- CREATE SCHEMA IF NOT EXISTS EcommerceDataset.SilverLayer;
-- CREATE SCHEMA IF NOT EXISTS EcommerceDataset.GoldLayer;
